# %% [markdown]
# # Topic Detection using Machine Learning

# %% [markdown]
# Importing Python Libraries
#
# Numpy http://www.numpy.org/
#
# NLTK https://www.nltk.org/
#
# Pandas https://pandas.pydata.org/
#
# TfLearn http://tflearn.org/
#
# RegexpTokenizer from NLTK http://www.nltk.org/api/nltk.tokenize.html
#
# SnowballStemmer from NLTK http://www.nltk.org/howto/stem.html
#
# Stopwords from NLTK https://pythonspot.com/nltk-stop-words/
#
# Training and Testing Data split from Sklearn http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
import numpy as np
import nltk
import os
import json
import datetime
import time
import random
import tensorflow as tf
import pandas as pd
import tflearn
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import train_test_split
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
stemmer = SnowballStemmer("english")
# Out:
# hdf5 is not supported on this machine (please install/reinstall h5py for optimal experience)
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)

# %%
random.seed(101)

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# Import the training_data.csv file with pandas.

# %%
#Reading the training data using Pandas 
dataset = pd.read_csv('train.csv')

#Printing out First Few Data 
dataset.head()
# Out:
#                                                Title Category    Topic
# 0  Ireland Votes To Overturn Abortion Ban, 'Culmi...    World  Ireland
# 1   Ireland overturns abortion ban in landslide vote    World  Ireland
# 2  Ireland votes to repeal abortion ban in landsl...    World  Ireland
# 3        Can Ireland Be Catholic Without the Church?    World  Ireland
# 4  The Latest: Irish PM Plans to Move Quickly on ...    World  Ireland

# %%
#Extracting Features X (Title) and Y (Topic) 

# title = dataset.iloc[:,0:1].values
# topic = dataset.iloc[:,3:4].values

title = dataset.iloc[:,0:1].values
topic = dataset.iloc[:,2:3].values

# %% [markdown]
# # Splitting The Dataset to X_train, X_test, y_train, y_test
#
# X_train contains 80% of the Title from DataSet
#
# y_train contains 80% of the Label
#
# Separate it into a training (80%) and testing set(20%).

# %%
#Splitting The Dataset to X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(title,topic,test_size=0.25,random_state=101)

# %% [markdown]
# Now The data has been split for traing and testing
#
# X_train and y_train is appened to a Json

# %%
training_data = []
topic_count = 0
for split_x in X_train:
    training_data.append({"title":split_x[0], "topic":y_train[topic_count][0]})
    topic_count+=1

# %% [markdown]
# # Cleaning our Training Data

# %%
words = []
topics = []
documents = []
ignore_words = ['?']
bin_words = [1]
print("{} sentences in training data".format(len(training_data)))
# Out:
# 1615 sentences in training data

# %%
# training_data

# %% [markdown]
# Using Regex Tokenizor to remove all the unwanted characters from "Title"
#
# aswell as Stopwords are removed
#
# Each sentence is split into words

# %%
tokenizer = RegexpTokenizer('\w{3,20}')
stop_words = set(stopwords.words('english'))
for pattern in training_data:
    w = tokenizer.tokenize(pattern['title'])
    w = [stemmer.stem(wr.lower()) for wr in w if wr not in stop_words]
    words.extend(w)
    documents.append((w, pattern['topic']))
    if pattern['topic'] not in topics:
        topics.append(pattern['topic'])

# %% [markdown]
# #### List of all words from the titles "Bag of words"

# %%
words = list(set(words))

# %%
# with open("jgi/words.json", 'w') as outfile:
#     json.dump(words, outfile)

# %%
print("There are {} words in corpus".format(len(words)))
# for wrd in words:
#     print(wrd,end='\t')
# Out:
# There are 2374 words in corpus

# %% [markdown]
# ### Lists all Labels saved in topics variable

# %%
topics = list(set(topics))
for tpc in topics:
    print(tpc,end='\t')
# Out:
# Nuclear Tests	Train	Cyclone	Spanish	Priyanka Chopra	Isreal	Spain	Xi Jinping	Sushma Swaraj	Celebrity	Education	Australia	Greece	Terrorism	Oman	Donald Trump	Monsoon Rain	Malaysia	Russia	Hillary Clinton	Taiwan	Colombia	Theresa May	Kim Jong Un	Pakistan	Turtle Day	FIFA World Cup	Israel	North Korea	Vladmir Putin	Vladimir Putin	Bangladesh	China	War	Britain	Ireland	Mark Zuckerberg	LGBT	World Turtle Day	Refugees	Egypt	Volcano	Venezuela	NASA	Eid Al Fitr	Rape	Nepal	Air Force	Italy	India	Myanmar	Crime	Michelle Obama	Brexit	Iran	Yemen	Germany	Harvey Weinstein	Politics	Religion	UAE	US Visa	Saudi Arabia	Nigeria	Iraq	Artificial Intelligence	Qatar	Palestine	Sri Lanka	Cuba	Ivanka Trump	Narendra Modi	Monsoon	USA

# %%
len(topics)
# Out:
# 74

# %%
# with open("jgi/topics.json", 'w') as outfile:
#     json.dump(topics, outfile)

# %% [markdown]
# # Creating our Training Data

# %% [markdown]
# ### Initializing variables

# %%
# create our training data
training = []
output = []
# create an empty array for our output
output_empty = [0] * len(topics)

# %% [markdown]
# #### Each title is tokenized, cleaned and represented as 0 or 1 according to "Bag of Words" created ealier

# %% [markdown]
# Tokenization is the process of breaking up the given text into units called tokens. The tokens may be words or number or punctuation mark. Tokenization does this task by locating word boundaries. Ending point of a word and beginning of the next word is called word boundaries. Tokenization is also known as word segmentation

# %% [markdown]
# Each training set appened to "training" variable

# %%
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # stem each word
    
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    pattern_words = [w for w in pattern_words if not w in stop_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag 
    output_row = list(output_empty)
    output_row[topics.index(doc[1])] = 1
    training.append([bag, output_row])

# %% [markdown]
# Trained data is shuffled to produce better results

# %%
# shuffle our features and turn into np.array
# random.shuffle(training)
training = np.array(training)

# trainX contains the Bag of words and train_y contains the label/ category
train_xi = list(training[:,0])
train_yi = list(training[:,1])

# %% [markdown]
# # Training

# %% [markdown]
# Trainig using TfLearn , TfLearn is a High level Tensorflow library

# %% [markdown]
# ### Building The Neural network with SoftMax activation function

# %%
# reset underlying graph data
tf.reset_default_graph()
# Build neural network
net = tflearn.input_data(shape=[None, len(train_xi[0])],dtype=tf.float32)
net = tflearn.fully_connected(net, 8,activation='relu')
net = tflearn.fully_connected(net, 8,activation='relu')
net = tflearn.fully_connected(net, len(train_yi[0]), activation='softmax')
net = tflearn.regression(net,dtype=tf.float32)

# %% [markdown]
# ### Define the Densely Connected Network

# %%
# Define model and setup tensorboard
model = tflearn.DNN(net, tensorboard_dir='tflearn_logs')

session = tf.get_default_session()
# tf.train.write_graph(tf.get_default_graph(), 'jgi', 'model.pbtxt')

# Start training (apply gradient descent algorithm)
model.fit(train_xi, train_yi, n_epoch=50, batch_size=8, show_metric=True)

# model.save('jgi/model.ckpt')
# model.load("jgi/demo_model.ckpt")
# Out:
# Training Step: 10099  | total loss: 0.61092 | time: 0.753s
# | Adam | epoch: 050 | loss: 0.61092 - acc: 0.8142 -- iter: 1608/1615
# Training Step: 10100  | total loss: 0.56896 | time: 0.756s
# | Adam | epoch: 050 | loss: 0.56896 - acc: 0.8202 -- iter: 1615/1615
# --

# %% [markdown]
# # Testing

# %%
# a method that takes in a sentence and list of all words
# and returns the data in a form the can be fed to tensorflow
def get_tf_record(sentence):
    global words
    # tokenize the pattern
    tokenizer = RegexpTokenizer('\w{3,20}')
    sentence_words = tokenizer.tokenize(sentence)
    # stem each word
#     sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    sentence_words = [stemmer.stem(wr.lower()) for wr in sentence_words if wr not in stop_words]
    print(sentence_words)
    # bag of words
    bow = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bow[i] = 1
    return(np.array(bow))

# %% [markdown]
# ### Argmax returns the Labels with Higher Probability

# %% [markdown]
# Here the Accuracy of the model is pretty low due to the training dataset size
#
# Some of the predictions are wrong

# %%
print(topics[np.argmax(model.predict([get_tf_record("US warships sail near disputed islands in South China Sea in a move likely to anger Beijing")]))])
# Out:
# ['warship', 'sail', 'near', 'disput', 'island', 'south', 'china', 'sea', 'move', 'like', 'anger', 'beij']
# USA

# %%
model.predict([get_tf_record("Extraterrestrial Life On Saturn's Icy Moon May Flourish")])[0]
# Out:
# ['extraterrestri', 'life', 'saturn', 'ici', 'moon', 'may', 'flourish']
# array([  5.94636193e-03,   8.56299046e-03,   2.66240204e-06,
#          5.15639503e-03,   6.38007239e-14,   4.16797957e-05,
#          8.74681922e-04,   4.32086475e-02,   2.44178344e-03,
#          4.79879227e-11,   4.14645541e-07,   1.13350356e-12,
#          2.94380989e-05,   7.97950197e-04,   4.29709324e-10,
#          6.29946817e-10,   1.81450574e-07,   4.20901272e-03,
#          1.05753288e-01,   5.36084099e-06,   4.22972931e-07,
#          3.33605943e-09,   6.08945149e-04,   6.68953266e-19,
#          1.45975710e-03,   2.23739653e-06,   9.04916879e-03,
#          2.18329351e-05,   4.42393566e-10,   1.04957621e-03,
#          6.19847402e-02,   2.34375917e-03,   1.17670781e-04,
#          8.59066546e-02,   6.32161973e-04,   7.65076262e-13,
#          1.38316967e-08,   3.46679641e-09,   1.11032227e-06,
#          2.31049256e-07,   8.24319502e-10,   7.98883702e-05,
#          1.58021506e-02,   2.02302326e-04,   6.50374773e-07,
#          7.36335992e-11,   2.04810585e-05,   2.75488049e-10,
#          7.87378196e-03,   2.17789523e-02,   6.37836658e-11,
#          2.25993637e-02,   1.04042647e-06,   1.11860987e-02,
#          2.45446106e-03,   3.33287659e-07,   3.39102439e-06,
#          7.78254883e-09,   4.20108676e-01,   2.12505929e-05,
#          8.32298363e-04,   2.59934008e-09,   9.69024527e-10,
#          2.81294588e-11,   1.38108879e-01,   1.67666681e-09,
#          7.86770045e-08,   3.56137683e-03,   2.59060187e-07,
#          1.59409712e-03,   8.47809344e-13,   1.34699708e-02,
#          4.27575912e-08,   9.10340896e-05], dtype=float32)

# %%
model.predict([get_tf_record("US warships sail near disputed islands in South China Sea in a move likely to anger Beijing")])[0][27]
# Out:
# ['warship', 'sail', 'near', 'disput', 'island', 'south', 'china', 'sea', 'move', 'like', 'anger', 'beij']
# 0.0

# %%
np.argmax(model.predict([get_tf_record("Extraterrestrial Life On Saturn's Icy Moon May Flourish")]))
# Out:
# ['extraterrestri', 'life', 'saturn', 'ici', 'moon', 'may', 'flourish']
# 58

# %%
# we can start to predict the results for each of the 4 sentences

for x_split in X_test:
    print(x_split[0])
    print(topics[np.argmax(model.predict([get_tf_record(x_split[0])]))])
#     print(model.predict([get_tf_record(x_split[0])]))
    print("="*85)
# Out:
# Meghan Markle gets Duchess lessons from Queen Elizabeth's aide
# ['meghan', 'markl', 'get', 'duchess', 'lesson', 'queen', 'elizabeth', 'aid']
# Celebrity
# =====================================================================================
# Pakistan supports SCO's anti-terrorism efforts: Tehmina Janjua
# ['pakistan', 'support', 'sco', 'anti', 'terror', 'effort', 'tehmina', 'janjua']
# Pakistan
# =====================================================================================
# Russia forces among dozens dead in IS group east Syria attacks
# ['russia', 'forc', 'among', 'dozen', 'dead', 'group', 'east', 'syria', 'attack']
# Russia
# =====================================================================================
# Iran lists demands for staying in nuclear deal
# ['iran', 'list', 'demand', 'stay', 'nuclear', 'deal']
# Iran
# =====================================================================================
# At Harvard, Clinton warns of threats to American democracy
# ['harvard', 'clinton', 'warn', 'threat', 'american', 'democraci']
# India
# =====================================================================================
# Is Italy's government on a collision course with the EU?
# ['itali', 'govern', 'collis', 'cours']
# Italy
# =====================================================================================
# Spanish opposition demands Rajoy confidence vote
# ['spanish', 'opposit', 'demand', 'rajoy', 'confid', 'vote']
# Politics
# =====================================================================================
# Savita Halappanavar's father hails 'justice for daughter', thanks Irish voters for historic referendum on abortion
# ['savita', 'halappanavar', 'father', 'hail', 'justic', 'daughter', 'thank', 'irish', 'voter', 'histor', 'referendum', 'abort']
# Mark Zuckerberg
# =====================================================================================
# Pakistan To Host Its First SCO Anti-Terror Meet, India Will Attend
# ['pakistan', 'host', 'it', 'first', 'sco', 'anti', 'terror', 'meet', 'india', 'will', 'attend']
# Pakistan
# =====================================================================================
# France and Macron have buried allegations of Russian meddling
# ['franc', 'macron', 'buri', 'alleg', 'russian', 'meddl']
# Vladimir Putin
# =====================================================================================
# United Kingdom destroyed files on Tamil Tigers, India-Sri Lanka relations: The Guardian
# ['unit', 'kingdom', 'destroy', 'file', 'tamil', 'tiger', 'india', 'sri', 'lanka', 'relat', 'the', 'guardian']
# Politics
# =====================================================================================
# Israeli army kills two militants in Gaza border shelling: Report
# ['isra', 'armi', 'kill', 'two', 'milit', 'gaza', 'border', 'shell', 'report']
# Isreal
# =====================================================================================
# Donald Trump threatens aid cut to countries that do not stop MS-13 gang migrants
# ['donald', 'trump', 'threaten', 'aid', 'cut', 'countri', 'stop', 'gang', 'migrant']
# Donald Trump
# =====================================================================================
# Taiwan Is Running Out of Friends Fast as China Turns the Screws
# ['taiwan', 'run', 'out', 'friend', 'fast', 'china', 'turn', 'screw']
# Iran
# =====================================================================================
# 13 killed as heavy rains lash Sri Lanka
# ['kill', 'heavi', 'rain', 'lash', 'sri', 'lanka']
# Monsoon
# =====================================================================================
# Yulia Skripal, poisoned in nerve agent attack, says recovery slow and painful; 'lucky to have survived'
# ['yulia', 'skripal', 'poison', 'nerv', 'agent', 'attack', 'say', 'recoveri', 'slow', 'pain', 'lucki', 'surviv']
# Politics
# =====================================================================================
# Can Trump make Iran and North Korea capitulate?
# ['can', 'trump', 'make', 'iran', 'north', 'korea', 'capitul']
# North Korea
# =====================================================================================
# Putin orders a fun World Cup for all
# ['putin', 'order', 'fun', 'world', 'cup']
# FIFA World Cup
# =====================================================================================
# 10 killed in Bangladesh landslides
# ['kill', 'bangladesh', 'landslid']
# Bangladesh
# =====================================================================================
# Newton Emerson: Post-Brexit Irish Sea border exists already
# ['newton', 'emerson', 'post', 'brexit', 'irish', 'sea', 'border', 'exist', 'alreadi']
# Brexit
# =====================================================================================
# Air Force officer who vanished at height of Cold War turns up in Calif.
# ['air', 'forc', 'offic', 'vanish', 'height', 'cold', 'war', 'turn', 'calif']
# Iran
# =====================================================================================
# How Modi Is Broadening the Range and Scope of India's 'Act East' Policy
# ['how', 'modi', 'broaden', 'rang', 'scope', 'india', 'act', 'east', 'polici']
# Vladimir Putin
# =====================================================================================
# Abe and Mahathir agree to cooperate in addressing North Korea issues
# ['abe', 'mahathir', 'agre', 'cooper', 'address', 'north', 'korea', 'issu']
# Malaysia
# =====================================================================================
# Bound together by poetry
# ['bound', 'togeth', 'poetri']
# Religion
# =====================================================================================
# Netherlands, Australia hold Russia liable for downing MH17
# ['netherland', 'australia', 'hold', 'russia', 'liabl', 'down', 'mh17']
# Vladimir Putin
# =====================================================================================
# Macedonia and Greece: Deal after 27-year row over a name
# ['macedonia', 'greec', 'deal', 'year', 'row', 'name']
# Greece
# =====================================================================================
# Facebook's apology tour just raises more questions
# ['facebook', 'apolog', 'tour', 'rais', 'question']
# Mark Zuckerberg
# =====================================================================================
# Kim Jong Un commits to summit with Trump, denuclearization: South Korea
# ['kim', 'jong', 'commit', 'summit', 'trump', 'denuclear', 'south', 'korea']
# Donald Trump
# =====================================================================================
# Narendra Modi good at foreign relations
# ['narendra', 'modi', 'good', 'foreign', 'relat']
# Xi Jinping
# =====================================================================================
# Trump can no longer block users on Twitter as judge declares his feed a public forum
# ['trump', 'longer', 'block', 'user', 'twitter', 'judg', 'declar', 'feed', 'public', 'forum']
# Donald Trump
# =====================================================================================
# MS Aquarius: why did Spain accept the disputed migrant ship?
# ['aquarius', 'spain', 'accept', 'disput', 'migrant', 'ship']
# Israel
# =====================================================================================
# Heatwave kills nearly 180 people in Karachi: Edhi Foundation
# ['heatwav', 'kill', 'near', '180', 'peopl', 'karachi', 'edhi', 'foundat']
# Pakistan
# =====================================================================================
# Allowing Irish women access to abortion is a pressing human rights matter
# ['allow', 'irish', 'women', 'access', 'abort', 'press', 'human', 'right', 'matter']
# Ireland
# =====================================================================================
# US warships sail near disputed islands in South China Sea in a move likely to anger Beijing
# ['warship', 'sail', 'near', 'disput', 'island', 'south', 'china', 'sea', 'move', 'like', 'anger', 'beij']
# USA
# =====================================================================================
# No adverse effect of Cyclone Mekunu on Kerala coast, yet on alert
# ['advers', 'effect', 'cyclon', 'mekunu', 'kerala', 'coast', 'yet', 'alert']
# Cyclone
# =====================================================================================
# Speaker Nabih Berri, great survivor of Lebanese politics
# ['speaker', 'nabih', 'berri', 'great', 'survivor', 'lebanes', 'polit']
# Politics
# =====================================================================================
# Disclosures show Kushner's wealth and debt have risen
# ['disclosur', 'show', 'kushner', 'wealth', 'debt', 'risen']
# Ivanka Trump
# =====================================================================================
# UK Judge Orders Operation Blue Star Related Files to be Made Public
# ['judg', 'order', 'oper', 'blue', 'star', 'relat', 'file', 'made', 'public']
# Britain
# =====================================================================================
# Spain Joins List of Market Worries
# ['spain', 'join', 'list', 'market', 'worri']
# Narendra Modi
# =====================================================================================
# Call for sacking of Indian-origin chef Atul Kochhar in UAE after 'anti-Islam' tweet
# ['call', 'sack', 'indian', 'origin', 'chef', 'atul', 'kochhar', 'uae', 'anti', 'islam', 'tweet']
# Religion
# =====================================================================================
# Pompeo: US will walk away from North Korea summit rather than take bad deal
# ['pompeo', 'walk', 'away', 'north', 'korea', 'summit', 'rather', 'take', 'bad', 'deal']
# USA
# =====================================================================================
# Yulia Skripal, daughter of former Russian spy, says recovery from poisoning 'slow, painful'
# ['yulia', 'skripal', 'daughter', 'former', 'russian', 'spi', 'say', 'recoveri', 'poison', 'slow', 'pain']
# Crime
# =====================================================================================
# The North Korea summit farce makes it clear again: Trump is political Ebola
# ['the', 'north', 'korea', 'summit', 'farc', 'make', 'clear', 'trump', 'polit', 'ebola']
# USA
# =====================================================================================
# Four Russian military personnel killed in Syria's Deir al-Zor - Ifax
# ['four', 'russian', 'militari', 'personnel', 'kill', 'syria', 'deir', 'zor', 'ifax']
# Russia
# =====================================================================================
# Indiana school shooting: Male student is main suspect, 1 teacher and a student hurt
# ['indiana', 'school', 'shoot', 'male', 'student', 'main', 'suspect', 'teacher', 'student', 'hurt']
# Crime
# =====================================================================================
# Donald Trump cancels North Korea nuclear summit
# ['donald', 'trump', 'cancel', 'north', 'korea', 'nuclear', 'summit']
# Donald Trump
# =====================================================================================
# Nawaz knew little about 'foolish' Kargil op: ex-ISI chief
# ['nawaz', 'knew', 'littl', 'foolish', 'kargil', 'isi', 'chief']
# Politics
# =====================================================================================
# Trump Violates First Amendment by Blocking Twitter Users, Judge Says
# ['trump', 'violat', 'first', 'amend', 'block', 'twitter', 'user', 'judg', 'say']
# Donald Trump
# =====================================================================================
# Malaysia court sentences Australian woman to death for drug-trafficking
# ['malaysia', 'court', 'sentenc', 'australian', 'woman', 'death', 'drug', 'traffick']
# Israel
# =====================================================================================
# This Nigerian Man Paid Last Respects To His Father By Burying Him In A Brand New BMW X6
# ['this', 'nigerian', 'man', 'paid', 'last', 'respect', 'his', 'father', 'buri', 'him', 'brand', 'new', 'bmw']
# Michelle Obama
# =====================================================================================
# US disinvites China from multinational military exercise
# ['disinvit', 'china', 'multin', 'militari', 'exercis']
# USA
# =====================================================================================
# Clorox won't cut it. Volcanologists explain what it takes to clean up after Kilauea
# ['clorox', 'cut', 'volcanologist', 'explain', 'take', 'clean', 'kilauea']
# War
# =====================================================================================
# 15 killed, over 126000 affected by Sri Lanka's monsoon rains
# ['kill', '126000', 'affect', 'sri', 'lanka', 'monsoon', 'rain']
# Narendra Modi
# =====================================================================================
# At least 49 dead after boat capsizes on Congo River
# ['least', 'dead', 'boat', 'capsiz', 'congo', 'river']
# Terrorism
# =====================================================================================
# India, Sri Lanka Files Among 195 Documents Destroyed In Britain
# ['india', 'sri', 'lanka', 'file', 'among', '195', 'document', 'destroy', 'britain']
# Britain
# =====================================================================================
# Priyanka Chopra meets Rohingya refugees in Bangladesh
# ['priyanka', 'chopra', 'meet', 'rohingya', 'refuge', 'bangladesh']
# Celebrity
# =====================================================================================
# Being excluded from EU Galileo satellite system creates 'irreparable security risk' for UK, say ministers - Politics live
# ['be', 'exclud', 'galileo', 'satellit', 'system', 'creat', 'irrepar', 'secur', 'risk', 'say', 'minist', 'polit', 'live']
# Brexit
# =====================================================================================
# Watching, stunned, during the blowup of the G7 meeting
# ['watch', 'stun', 'blowup', 'meet']
# China
# =====================================================================================
# GUEST COLUMN: Iran will lose its war against free expression
# ['guest', 'column', 'iran', 'lose', 'war', 'free', 'express']
# Narendra Modi
# =====================================================================================
# Political unknown appointed Italy's new prime minister
# ['polit', 'unknown', 'appoint', 'itali', 'new', 'prime', 'minist']
# Narendra Modi
# =====================================================================================
# 111 now confirmed dead in Cuba plane crash
# ['111', 'confirm', 'dead', 'cuba', 'plane', 'crash']
# Cuba
# =====================================================================================
# North Korea's Nazi-style Prison Camps Not Discussed in Historic Trump-Kim Summit
# ['north', 'korea', 'nazi', 'style', 'prison', 'camp', 'not', 'discuss', 'histor', 'trump', 'kim', 'summit']
# Donald Trump
# =====================================================================================
# SCO assumes even greater importance with India, Pak entry: UN
# ['sco', 'assum', 'even', 'greater', 'import', 'india', 'pak', 'entri']
# Xi Jinping
# =====================================================================================
# Modi-Putin Informal Summit: New Delhi recalibrating ties with Moscow is a good sign
# ['modi', 'putin', 'inform', 'summit', 'new', 'delhi', 'recalibr', 'tie', 'moscow', 'good', 'sign']
# Venezuela
# =====================================================================================
# Rainbow Flags Fly Across Europe At Continental Gay Pride Parades
# ['rainbow', 'flag', 'fli', 'across', 'europ', 'continent', 'gay', 'pride', 'parad']
# LGBT
# =====================================================================================
# Fishing for the truth
# ['fish', 'truth']
# Politics
# =====================================================================================
# Avenfield reference: Nawaz shows up in court without lawyer
# ['avenfield', 'refer', 'nawaz', 'show', 'court', 'without', 'lawyer']
# India
# =====================================================================================
# Ireland's abortion decision: a photo essay
# ['ireland', 'abort', 'decis', 'photo', 'essay']
# Terrorism
# =====================================================================================
# China protests 'provocation' after two US ships sail near disputed islands
# ['china', 'protest', 'provoc', 'two', 'ship', 'sail', 'near', 'disput', 'island']
# USA
# =====================================================================================
# 15 injured after two men set off bomb in Indian restaurant in suburban Toronto, hunt on for suspects
# ['injur', 'two', 'men', 'set', 'bomb', 'indian', 'restaur', 'suburban', 'toronto', 'hunt', 'suspect']
# Terrorism
# =====================================================================================
# PM Narendra Modi, Sheikh Hasina hold talks at Santiniketan
# ['narendra', 'modi', 'sheikh', 'hasina', 'hold', 'talk', 'santiniketan']
# Narendra Modi
# =====================================================================================
# Dutch, Australia say Russia behind downing MH17
# ['dutch', 'australia', 'say', 'russia', 'behind', 'down', 'mh17']
# Malaysia
# =====================================================================================
# Yulia Skripal: 'We are so lucky to have survived assassination attempt'
# ['yulia', 'skripal', 'lucki', 'surviv', 'assassin', 'attempt']
# Politics
# =====================================================================================
# The Latest: Trump says US now 'talking to' NK about summit
# ['the', 'latest', 'trump', 'say', 'talk', 'summit']
# Donald Trump
# =====================================================================================
# Kim-Trump summit called-off: A lost opportunity or deliberate bid in a battle of egos?
# ['kim', 'trump', 'summit', 'call', 'lost', 'opportun', 'deliber', 'bid', 'battl', 'ego']
# Kim Jong Un
# =====================================================================================
# Italy PM-designate meets president as he assembles cabinet team
# ['itali', 'design', 'meet', 'presid', 'assembl', 'cabinet', 'team']
# Italy
# =====================================================================================
# Egypt court upholds 2013 verdict banning YouTube for one month
# ['egypt', 'court', 'uphold', '2013', 'verdict', 'ban', 'youtub', 'one', 'month']
# Egypt
# =====================================================================================
# Tipping point in West Asia
# ['tip', 'point', 'west', 'asia']
# Iran
# =====================================================================================
# Ireland votes in historic abortion referendum
# ['ireland', 'vote', 'histor', 'abort', 'referendum']
# Ireland
# =====================================================================================
# Eurocracts fear for worst as 'barbarians' take over in Rome
# ['eurocract', 'fear', 'worst', 'barbarian', 'take', 'rome']
# Politics
# =====================================================================================
# Trump and Kim Shake Hands, but Asian Markets Are Mostly Flat
# ['trump', 'kim', 'shake', 'hand', 'asian', 'market', 'are', 'most', 'flat']
# Donald Trump
# =====================================================================================
# #AM_Equality Tipsheet: June 11, 2018
# ['am_equ', 'tipsheet', 'june', '2018']
# Politics
# =====================================================================================
# US seeks probe on Hindus massacred in Myanmar; Muslim groups slam Amnesty
# ['seek', 'probe', 'hindus', 'massacr', 'myanmar', 'muslim', 'group', 'slam', 'amnesti']
# Myanmar
# =====================================================================================
# Unlike any other: A tough Ramadan in Gaza
# ['unlik', 'tough', 'ramadan', 'gaza']
# Narendra Modi
# =====================================================================================
# Twists and turns of US-North Korean diplomatic rollercoaster
# ['twist', 'turn', 'north', 'korean', 'diplomat', 'rollercoast']
# Donald Trump
# =====================================================================================
# New Probe Says Rohingya Militants Massacred Civilians
# ['new', 'probe', 'say', 'rohingya', 'milit', 'massacr', 'civilian']
# Politics
# =====================================================================================
# Everything you need to know about Theresa May's Brexit bill showdown
# ['everyth', 'need', 'know', 'theresa', 'may', 'brexit', 'bill', 'showdown']
# Britain
# =====================================================================================
# On day of summit with Trump, Kim also greets Russian President Putin
# ['day', 'summit', 'trump', 'kim', 'also', 'greet', 'russian', 'presid', 'putin']
# Russia
# =====================================================================================
# US ambassador to Israel 'taken advantage of' when photographed with Jerusalem poster
# ['ambassador', 'israel', 'taken', 'advantag', 'photograph', 'jerusalem', 'poster']
# USA
# =====================================================================================
# Premature Heat Wave Increases Odds of More 90s This Summer
# ['prematur', 'heat', 'wave', 'increas', 'odd', 'more', '90s', 'this', 'summer']
# India
# =====================================================================================
# Noblesville, Indiana, school shooting is at least the 21st of 2018
# ['noblesvill', 'indiana', 'school', 'shoot', 'least', '21st', '2018']
# Crime
# =====================================================================================
# Pakistan Approves Bill to Merge Tribal Regions With Country
# ['pakistan', 'approv', 'bill', 'merg', 'tribal', 'region', 'with', 'countri']
# Pakistan
# =====================================================================================
# Cyclone Mekunu intensifies as it pounds Oman
# ['cyclon', 'mekunu', 'intensifi', 'pound', 'oman']
# Cyclone
# =====================================================================================
# Rajoy Government in Spain Is Threatened by Verdicts in Corruption Case
# ['rajoy', 'govern', 'spain', 'threaten', 'verdict', 'corrupt', 'case']
# Xi Jinping
# =====================================================================================
# Venezuelan dictator Maduro is ensconced for the long haul, unfortunately
# ['venezuelan', 'dictat', 'maduro', 'ensconc', 'long', 'haul', 'unfortun']
# Politics
# =====================================================================================
# New financial disclosure shows growing Jared Kushner wealth, debt
# ['new', 'financi', 'disclosur', 'show', 'grow', 'jare', 'kushner', 'wealth', 'debt']
# Air Force
# =====================================================================================
# Priyanka on Rohingya refugees: While their lives are safer now, they are still struggling
# ['priyanka', 'rohingya', 'refuge', 'while', 'live', 'safer', 'still', 'struggl']
# Priyanka Chopra
# =====================================================================================
# Donald Trump calls for new 'structure' for US-China trade deal
# ['donald', 'trump', 'call', 'new', 'structur', 'china', 'trade', 'deal']
# Donald Trump
# =====================================================================================
# Pak's Khyber Pakhtunkhwa assembly passes landmark bill to merge FATA with province
# ['pak', 'khyber', 'pakhtunkhwa', 'assembl', 'pass', 'landmark', 'bill', 'merg', 'fata', 'provinc']
# Pakistan
# =====================================================================================
# Ireland votes in historic abortion referendum
# ['ireland', 'vote', 'histor', 'abort', 'referendum']
# Ireland
# =====================================================================================
# China Is Pakistan's "Iron Friend," But This Isn't What Friends Do
# ['china', 'pakistan', 'iron', 'friend', 'but', 'this', 'isn', 'what', 'friend']
# China
# =====================================================================================
# 2 hurt in Indiana middle school shooting; suspect detained
# ['hurt', 'indiana', 'middl', 'school', 'shoot', 'suspect', 'detain']
# Crime
# =====================================================================================
# Tory MP Andrea Jenkyns quits government role 'to fight for Brexit'
# ['tori', 'andrea', 'jenkyn', 'quit', 'govern', 'role', 'fight', 'brexit']
# Brexit
# =====================================================================================
# India, Bangladesh bonded by cooperation and understanding: PM Narendra Modi
# ['india', 'bangladesh', 'bond', 'cooper', 'understand', 'narendra', 'modi']
# Narendra Modi
# =====================================================================================
# Pakistan Actively Involved in Kashmir Turmoil, Hints Former ISI Chief Asad Durrani
# ['pakistan', 'activ', 'involv', 'kashmir', 'turmoil', 'hint', 'former', 'isi', 'chief', 'asad', 'durrani']
# Pakistan
# =====================================================================================
# Almost USD 30 million, 400 handbags seized in raids linked to Malaysia's Najib
# ['almost', 'usd', 'million', '400', 'handbag', 'seiz', 'raid', 'link', 'malaysia', 'najib']
# Malaysia
# =====================================================================================
# India kept its interests 'safe' at SCO Summit (News Analysis)
# ['india', 'kept', 'interest', 'safe', 'sco', 'summit', 'news', 'analysi']
# Narendra Modi
# =====================================================================================
# India lodges protest with Pakistan deputy HC over Gilgit-Baltistan order
# ['india', 'lodg', 'protest', 'pakistan', 'deputi', 'gilgit', 'baltistan', 'order']
# India
# =====================================================================================
# Islamic State claims responsibility for Baghdad blast: group's news agency Amaq
# ['islam', 'state', 'claim', 'respons', 'baghdad', 'blast', 'group', 'news', 'agenc', 'amaq']
# Crime
# =====================================================================================
# Exclusive: Attempted assassination turned my world upside down - Yulia Skripal
# ['exclus', 'attempt', 'assassin', 'turn', 'world', 'upsid', 'yulia', 'skripal']
# Politics
# =====================================================================================
# United Kingdom sees more than 60000 lightning strikes during thunderstorms
# ['unit', 'kingdom', 'see', '60000', 'lightn', 'strike', 'thunderstorm']
# Britain
# =====================================================================================
# Critics see no end to foreign favours to Trump businesses
# ['critic', 'see', 'end', 'foreign', 'favour', 'trump', 'busi']
# Donald Trump
# =====================================================================================
# 2 men sought after bomb blast at Mississauga restaurant wounds 15
# ['men', 'sought', 'bomb', 'blast', 'mississauga', 'restaur', 'wound']
# Terrorism
# =====================================================================================
# Is the US Bringing Europe and Russia Closer Together?
# ['bring', 'europ', 'russia', 'closer', 'togeth']
# Politics
# =====================================================================================
# Singapore summit closely watched by Korean Americans
# ['singapor', 'summit', 'close', 'watch', 'korean', 'american']
# North Korea
# =====================================================================================
# Trump and Kim raise summit hopes after days of brinkmanship
# ['trump', 'kim', 'rais', 'summit', 'hope', 'day', 'brinkmanship']
# Kim Jong Un
# =====================================================================================
# Kim vows full denuclearisation, Trump guarantees security at historic meet
# ['kim', 'vow', 'full', 'denuclearis', 'trump', 'guarante', 'secur', 'histor', 'meet']
# Kim Jong Un
# =====================================================================================
# German FM: Europe 'Very United' On Decision To Stay In Iran Deal
# ['german', 'europ', 'veri', 'unit', 'decis', 'stay', 'iran', 'deal']
# Iran
# =====================================================================================
# Landslides Kill 11 As Monsoon Batters Rohingya Refugees
# ['landslid', 'kill', 'monsoon', 'batter', 'rohingya', 'refuge']
# Myanmar
# =====================================================================================
# It is welcome news that the Korea summit is once again set to go ahead –particularly for those living in the south
# ['welcom', 'news', 'korea', 'summit', 'set', 'ahead', 'particular', 'live', 'south']
# Kim Jong Un
# =====================================================================================
# NRA Met with Close Putin Allies During 2016 Election
# ['nra', 'met', 'close', 'putin', 'alli', 'dure', '2016', 'elect']
# Xi Jinping
# =====================================================================================
# UK judge orders Operation Blue Star related files to be made public
# ['judg', 'order', 'oper', 'blue', 'star', 'relat', 'file', 'made', 'public']
# Britain
# =====================================================================================
# Back-Slapping Donald Trump Summit Legitimises Kim Jong Un, Say Critics
# ['back', 'slap', 'donald', 'trump', 'summit', 'legitimis', 'kim', 'jong', 'say', 'critic']
# Donald Trump
# =====================================================================================
# Israel to build 2 500 more settler homes in occupied West Bank
# ['israel', 'build', '500', 'settler', 'home', 'occupi', 'west', 'bank']
# Israel
# =====================================================================================
# United Kingdom destroyed files on Tamil Tigers, India-Sri Lanka relations: The Guardian
# ['unit', 'kingdom', 'destroy', 'file', 'tamil', 'tiger', 'india', 'sri', 'lanka', 'relat', 'the', 'guardian']
# Politics
# =====================================================================================
# Priyanka Chopra urges world to step up support for Rohingya women, children
# ['priyanka', 'chopra', 'urg', 'world', 'step', 'support', 'rohingya', 'women', 'children']
# Bangladesh
# =====================================================================================
# Sheikh Hasina expresses gratitude to India for 'standing' beside Bangladesh in times of crisis
# ['sheikh', 'hasina', 'express', 'gratitud', 'india', 'stand', 'besid', 'bangladesh', 'time', 'crisi']
# Narendra Modi
# =====================================================================================
# Sick & tired of US foreign policy, Germany is pushed into the open arms of China
# ['sick', 'tire', 'foreign', 'polici', 'germani', 'push', 'open', 'arm', 'china']
# China
# =====================================================================================
# The Finance 202: Republican senators only willing to go so far in challenging Trump on trade
# ['the', 'financ', '202', 'republican', 'senat', 'will', 'far', 'challeng', 'trump', 'trade']
# Donald Trump
# =====================================================================================
# Israel Mulls Hundreds of New Settlement Homes – Defense Minister Touts Over 2000
# ['israel', 'mull', 'hundr', 'new', 'settlement', 'home', 'defens', 'minist', 'tout', 'over', '2000']
# Politics
# =====================================================================================
# G7 leaders must take action on Burma
# ['leader', 'must', 'take', 'action', 'burma']
# Bangladesh
# =====================================================================================
# Four of the EU's harshest hits against Facebook CEO Mark Zuckerberg
# ['four', 'harshest', 'hit', 'facebook', 'ceo', 'mark', 'zuckerberg']
# Mark Zuckerberg
# =====================================================================================
# Federal Court Rules that President Trump's Blocking of Twitter Critics Violates First Amendment | Knight First ...
# ['feder', 'court', 'rule', 'presid', 'trump', 'block', 'twitter', 'critic', 'violat', 'first', 'amend', 'knight', 'first']
# Donald Trump
# =====================================================================================
# The Latest: Student says science teacher tackled gunman
# ['the', 'latest', 'student', 'say', 'scienc', 'teacher', 'tackl', 'gunman']
# Crime
# =====================================================================================
# Prince William becomes first Royal to mark official visit to Israel
# ['princ', 'william', 'becom', 'first', 'royal', 'mark', 'offici', 'visit', 'israel']
# Celebrity
# =====================================================================================
# Feckless West can't keep falling for Hamas propaganda
# ['feckless', 'west', 'keep', 'fall', 'hama', 'propaganda']
# Isreal
# =====================================================================================
# Social Humour: Trump-Kim's historic meet floods Internet with memes
# ['social', 'humour', 'trump', 'kim', 'histor', 'meet', 'flood', 'internet', 'meme']
# Donald Trump
# =====================================================================================
# India set to miss key target for Japan-backed bullet train project: Sources
# ['india', 'set', 'miss', 'key', 'target', 'japan', 'back', 'bullet', 'train', 'project', 'sourc']
# Russia
# =====================================================================================
# India, Bangladesh bonded by cooperation and understanding: PM Narendra Modi
# ['india', 'bangladesh', 'bond', 'cooper', 'understand', 'narendra', 'modi']
# Narendra Modi
# =====================================================================================
# Netanyahu questioned in German submarine case: spokesman
# ['netanyahu', 'question', 'german', 'submarin', 'case', 'spokesman']
# Crime
# =====================================================================================
# Strategic Ties Between India and the US Are Growing. But Russia Is a Stumbling Block
# ['strateg', 'tie', 'between', 'india', 'are', 'grow', 'but', 'russia', 'stumbl', 'block']
# Politics
# =====================================================================================
# Nobody Asks India To Control Its Nuclear Assets, Says Pervez Musharraf
# ['nobodi', 'ask', 'india', 'control', 'it', 'nuclear', 'asset', 'say', 'pervez', 'musharraf']
# Vladimir Putin
# =====================================================================================
# Donald Trump revives hope for summit with Kim Jong-un; says date and location 'hasn't changed'
# ['donald', 'trump', 'reviv', 'hope', 'summit', 'kim', 'jong', 'say', 'date', 'locat', 'chang']
# Kim Jong Un
# =====================================================================================
# No lawyer willing to fight my case: Nawaz Sharif
# ['lawyer', 'will', 'fight', 'case', 'nawaz', 'sharif']
# Pakistan
# =====================================================================================
# Trump May Impose Tariffs on Foreign Autos
# ['trump', 'may', 'impos', 'tariff', 'foreign', 'auto']
# Donald Trump
# =====================================================================================
# The Latest: S. Korea PM sad that Trump-Kim summit canceled
# ['the', 'latest', 'korea', 'sad', 'trump', 'kim', 'summit', 'cancel']
# Donald Trump
# =====================================================================================
# Modi, Hasina discuss bilateral issues, security at Santiniketan meet (Roundup)
# ['modi', 'hasina', 'discuss', 'bilater', 'issu', 'secur', 'santiniketan', 'meet', 'roundup']
# Malaysia
# =====================================================================================
# Cyclone Mekunu heads for popular Omani resort after pummeling UNESCO-protected Socotra island
# ['cyclon', 'mekunu', 'head', 'popular', 'omani', 'resort', 'pummel', 'unesco', 'protect', 'socotra', 'island']
# Cyclone
# =====================================================================================
# Trump-Kim meet: A story of two nuclear powers
# ['trump', 'kim', 'meet', 'stori', 'two', 'nuclear', 'power']
# Donald Trump
# =====================================================================================
# US cancels invitation to China to join naval exercises
# ['cancel', 'invit', 'china', 'join', 'naval', 'exercis']
# Malaysia
# =====================================================================================
# Four of the EU's harshest hits against Facebook CEO Mark Zuckerberg
# ['four', 'harshest', 'hit', 'facebook', 'ceo', 'mark', 'zuckerberg']
# Mark Zuckerberg
# =====================================================================================
# US Congress Sends "Right To Try" Experimental Drug Bill To President Donald Trump
# ['congress', 'send', 'right', 'tri', 'experiment', 'drug', 'bill', 'presid', 'donald', 'trump']
# USA
# =====================================================================================
# US warships sail within China's claimed territorial waters in Parcel Islands as evidence shows new missiles, fighters there
# ['warship', 'sail', 'within', 'china', 'claim', 'territori', 'water', 'parcel', 'island', 'evid', 'show', 'new', 'missil', 'fighter']
# USA
# =====================================================================================
# Putin meets intl news agencies heads at St Petersburg Economic Forum
# ['putin', 'meet', 'intl', 'news', 'agenc', 'head', 'petersburg', 'econom', 'forum']
# India
# =====================================================================================
# Yemeni president in UAE amid reports of imminent Hodeidah offensive
# ['yemeni', 'presid', 'uae', 'amid', 'report', 'immin', 'hodeidah', 'offens']
# Monsoon
# =====================================================================================
# Pak borrows USD 1 billion from Chinese banks to avoid crisis: Report
# ['pak', 'borrow', 'usd', 'billion', 'chines', 'bank', 'avoid', 'crisi', 'report']
# Pakistan
# =====================================================================================
# Trump says summit with North Korea may still be on
# ['trump', 'say', 'summit', 'north', 'korea', 'may', 'still']
# Donald Trump
# =====================================================================================
# Rainbow Flags Fly Across Europe At Continental Gay Pride Parades
# ['rainbow', 'flag', 'fli', 'across', 'europ', 'continent', 'gay', 'pride', 'parad']
# LGBT
# =====================================================================================
# Rohingya Militants Responsible For Killing Nearly 100 Hindus in Myanmar's Rakhine State: Report
# ['rohingya', 'milit', 'respons', 'for', 'kill', 'near', '100', 'hindus', 'myanmar', 'rakhin', 'state', 'report']
# Myanmar
# =====================================================================================
# World Digest: May 23, 2018
# ['world', 'digest', 'may', '2018']
# Malaysia
# =====================================================================================
# 14 killed as landslides sweep away Rohingya shelters in Bangladesh
# ['kill', 'landslid', 'sweep', 'away', 'rohingya', 'shelter', 'bangladesh']
# Myanmar
# =====================================================================================
# Iran has legal right to uranium enrichment: Qassemi
# ['iran', 'legal', 'right', 'uranium', 'enrich', 'qassemi']
# Iran
# =====================================================================================
# Student Says Teacher Tackled Shootout by Student in Yet Another Incident at US School
# ['student', 'say', 'teacher', 'tackl', 'shootout', 'student', 'yet', 'anoth', 'incid', 'school']
# Crime
# =====================================================================================
# Almost A Year After Embargo Hit Qatar, Doha Bans Goods From UAE, Saudi
# ['almost', 'year', 'after', 'embargo', 'hit', 'qatar', 'doha', 'ban', 'good', 'from', 'uae', 'saudi']
# Narendra Modi
# =====================================================================================
# 2 hurt in Indiana middle school shooting; suspect detained
# ['hurt', 'indiana', 'middl', 'school', 'shoot', 'suspect', 'detain']
# Crime
# =====================================================================================
# Bombing at Ontario Indian Restaurant Leaves 15 Injured
# ['bomb', 'ontario', 'indian', 'restaur', 'leav', 'injur']
# Terrorism
# =====================================================================================
# 'Trump blocking critics on Twitter violates Constitution'
# ['trump', 'block', 'critic', 'twitter', 'violat', 'constitut']
# Donald Trump
# =====================================================================================
# Pakistan parliament passes landmark tribal areas reform
# ['pakistan', 'parliament', 'pass', 'landmark', 'tribal', 'area', 'reform']
# Pakistan
# =====================================================================================
# Mid, small-caps outperform in four years of Narendra Modi government
# ['mid', 'small', 'cap', 'outperform', 'four', 'year', 'narendra', 'modi', 'govern']
# Italy
# =====================================================================================
# Shadowy social media ads could influence Irish abortion vote, watchdog says
# ['shadowi', 'social', 'media', 'ad', 'could', 'influenc', 'irish', 'abort', 'vote', 'watchdog', 'say']
# Ireland
# =====================================================================================
# GDPR is here: Mess Up and we'll fine you, warns EU privacy chief
# ['gdpr', 'mess', 'fine', 'warn', 'privaci', 'chief']
# Pakistan
# =====================================================================================
# Nawaz Sharif accuses Pakistan SC chief justice of oppression, injustice
# ['nawaz', 'sharif', 'accus', 'pakistan', 'chief', 'justic', 'oppress', 'injustic']
# Pakistan
# =====================================================================================
# Ireland passes historic law on abortion: Twitterati remember the Indian woman who became the symbol for change
# ['ireland', 'pass', 'histor', 'law', 'abort', 'twitterati', 'rememb', 'indian', 'woman', 'becam', 'symbol', 'chang']
# Terrorism
# =====================================================================================
# FIFA Cup: Hush, The Neo-Nazi Whispers In Moscow
# ['fifa', 'cup', 'hush', 'the', 'neo', 'nazi', 'whisper', 'moscow']
# Greece
# =====================================================================================
# Why Colombians distrust the FARC peace deal
# ['whi', 'colombian', 'distrust', 'farc', 'peac', 'deal']
# Vladimir Putin
# =====================================================================================
# Italy president under pressure to accept eurosceptic minister
# ['itali', 'presid', 'pressur', 'accept', 'euroscept', 'minist']
# Religion
# =====================================================================================
# Theresa May's Irish stew
# ['theresa', 'may', 'irish', 'stew']
# Terrorism
# =====================================================================================
# Yulia Skripal says her recovery from poisoning has been 'slow, painful'
# ['yulia', 'skripal', 'say', 'recoveri', 'poison', 'slow', 'pain']
# Politics
# =====================================================================================
# Colombians vote for new president in wake of Farc peace process
# ['colombian', 'vote', 'new', 'presid', 'wake', 'farc', 'peac', 'process']
# Colombia
# =====================================================================================
# How do we welcome Ramadan?
# ['how', 'welcom', 'ramadan']
# Religion
# =====================================================================================
# Hunt on for two suspects as 15 people injured in Mississauga restaurant explosion
# ['hunt', 'two', 'suspect', 'peopl', 'injur', 'mississauga', 'restaur', 'explos']
# Terrorism
# =====================================================================================
# Extreme Weather Causes Production Outages In Libya
# ['extrem', 'weather', 'caus', 'product', 'outag', 'libya']
# Narendra Modi
# =====================================================================================
# Italian PM nominee in talks to form Cabinet
# ['italian', 'nomine', 'talk', 'form', 'cabinet']
# Italy
# =====================================================================================
# The Latest: S. Korea PM sad that Trump-Kim summit canceled
# ['the', 'latest', 'korea', 'sad', 'trump', 'kim', 'summit', 'cancel']
# Donald Trump
# =====================================================================================
# Feckless West can't keep falling for Hamas propaganda
# ['feckless', 'west', 'keep', 'fall', 'hama', 'propaganda']
# Isreal
# =====================================================================================
# Pak heatwave kills 65 people in Karachi: Report
# ['pak', 'heatwav', 'kill', 'peopl', 'karachi', 'report']
# Pakistan
# =====================================================================================
# Taiwan Is Running Out of Friends Fast as China Turns the Screws
# ['taiwan', 'run', 'out', 'friend', 'fast', 'china', 'turn', 'screw']
# Iran
# =====================================================================================
# New evidence reveals Muslim-majority Rohingya massacred 105 Hindus: Amnesty
# ['new', 'evid', 'reveal', 'muslim', 'major', 'rohingya', 'massacr', '105', 'hindus', 'amnesti']
# Myanmar
# =====================================================================================
# Pak Army summons ex-ISI chief over co-authoring book with ex-RAW chief
# ['pak', 'armi', 'summon', 'isi', 'chief', 'author', 'book', 'raw', 'chief']
# Pakistan
# =====================================================================================
# Trump-Kim meet: The carrots US offers North will define the deal's success
# ['trump', 'kim', 'meet', 'the', 'carrot', 'offer', 'north', 'defin', 'deal', 'success']
# Donald Trump
# =====================================================================================
# US seeks probe on Hindus massacred in Myanmar; Muslim groups slam Amnesty
# ['seek', 'probe', 'hindus', 'massacr', 'myanmar', 'muslim', 'group', 'slam', 'amnesti']
# Myanmar
# =====================================================================================
# Kim promises complete denuclearisation in return for security guarantees from Trump
# ['kim', 'promis', 'complet', 'denuclearis', 'return', 'secur', 'guarante', 'trump']
# Donald Trump
# =====================================================================================
# Pakistan looks to China for bail out from financial crisis: FT
# ['pakistan', 'look', 'china', 'bail', 'financi', 'crisi']
# Pakistan
# =====================================================================================
# US Cautions Its Citizens In China After 'Abnormal' Sound Incident
# ['caution', 'it', 'citizen', 'china', 'after', 'abnorm', 'sound', 'incid']
# USA
# =====================================================================================
# US House Backs Measures to Sanction Myanmar's Military, Nudge Gem Sector Reform
# ['hous', 'back', 'measur', 'sanction', 'myanmar', 'militari', 'nudg', 'gem', 'sector', 'reform']
# Myanmar
# =====================================================================================
# To stop school shootings, use Israel's approach to fighting terror: Texas attorney general
# ['stop', 'school', 'shoot', 'use', 'israel', 'approach', 'fight', 'terror', 'texa', 'attorney', 'general']
# Politics
# =====================================================================================
# Putin and Macron question Trump's withdrawal from Iran deal and North Korea summit
# ['putin', 'macron', 'question', 'trump', 'withdraw', 'iran', 'deal', 'north', 'korea', 'summit']
# USA
# =====================================================================================
# Trump Signs 'Comprehensive Document' With Kim as Summit Ends
# ['trump', 'sign', 'comprehens', 'document', 'with', 'kim', 'summit', 'end']
# Kim Jong Un
# =====================================================================================
# Priyanka Chopra visits Rohingya kids in Bangladesh, says, children are the future citizens and shouldn't be divided
# ['priyanka', 'chopra', 'visit', 'rohingya', 'kid', 'bangladesh', 'say', 'children', 'futur', 'citizen', 'divid']
# Priyanka Chopra
# =====================================================================================
# Taiwan and China: A battle for sovereignty or diversity?
# ['taiwan', 'china', 'battl', 'sovereignti', 'divers']
# USA
# =====================================================================================
# US ambassador to Israel 'taken advantage of' when photographed with Jerusalem poster
# ['ambassador', 'israel', 'taken', 'advantag', 'photograph', 'jerusalem', 'poster']
# USA
# =====================================================================================
# Tory MP Andrea Jenkyns quits government role 'to fight for Brexit'
# ['tori', 'andrea', 'jenkyn', 'quit', 'govern', 'role', 'fight', 'brexit']
# Brexit
# =====================================================================================
# Trump's words carry loathsome baggage
# ['trump', 'word', 'carri', 'loathsom', 'baggag']
# India
# ...
# Narendra Modi
# =====================================================================================
# Israeli court approves razing West Bank Bedouin village
# ['isra', 'court', 'approv', 'raze', 'west', 'bank', 'bedouin', 'villag']
# Israel
# =====================================================================================
# TABLE-India's May oil imports up 2.8 pct year-on-year - trade
# ['tabl', 'india', 'may', 'oil', 'import', 'pct', 'year', 'year', 'trade']
# USA
# =====================================================================================
# Bahrain FM: No Glimmer of Hope in Resolving Crisis with Qatar Now
# ['bahrain', 'glimmer', 'hope', 'resolv', 'crisi', 'qatar', 'now']
# War
# =====================================================================================
# MAI tasks world leaders, Rights groups, individuals on Gaza
# ['mai', 'task', 'world', 'leader', 'right', 'group', 'individu', 'gaza']
# India
# =====================================================================================
# One year after LGBT pride event curtailment at Vicenza, soldiers will take the stage
# ['one', 'year', 'lgbt', 'pride', 'event', 'curtail', 'vicenza', 'soldier', 'take', 'stage']
# LGBT
# =====================================================================================
# Can South Korea Save the Summit?
# ['can', 'south', 'korea', 'save', 'summit']
# Donald Trump
# =====================================================================================
# 'Active shooter' taken into custody at Indiana middle school
# ['activ', 'shooter', 'taken', 'custodi', 'indiana', 'middl', 'school']
# Crime
# =====================================================================================
# Donald Trump-Kim Jong Un summit pleases China
# ['donald', 'trump', 'kim', 'jong', 'summit', 'pleas', 'china']
# Donald Trump
# =====================================================================================
# Ex-spy's daughter Yulia Skripal says she is lucky to be alive after nerve attack, hopes to return to Russia
# ['spi', 'daughter', 'yulia', 'skripal', 'say', 'lucki', 'aliv', 'nerv', 'attack', 'hope', 'return', 'russia']
# Politics
# =====================================================================================
# Pacific Ocean features in new royal Markle's Coat of Arms
# ['pacif', 'ocean', 'featur', 'new', 'royal', 'markl', 'coat', 'arm']
# FIFA World Cup
# =====================================================================================
# Trump and Kim pledge peace and denuclearisation in Korean peninsula amid skepticism
# ['trump', 'kim', 'pledg', 'peac', 'denuclearis', 'korean', 'peninsula', 'amid', 'skeptic']
# Donald Trump
# =====================================================================================
# Merkel, Chinese premier defend Iran deal, free trade
# ['merkel', 'chines', 'premier', 'defend', 'iran', 'deal', 'free', 'trade']
# Iran
# =====================================================================================
# Air Force officer who vanished at height of Cold War turns up in Calif.
# ['air', 'forc', 'offic', 'vanish', 'height', 'cold', 'war', 'turn', 'calif']
# Iran
# =====================================================================================
# NSC should meet over 'ISI-RAW' book: Sharif
# ['nsc', 'meet', 'isi', 'raw', 'book', 'sharif']
# Pakistan
# =====================================================================================
# Giuseppe Conte approved for Italian prime minister
# ['giusepp', 'cont', 'approv', 'italian', 'prime', 'minist']
# Italy
# =====================================================================================
# Kim Jong Un commits to summit with Trump, denuclearization: South Korea
# ['kim', 'jong', 'commit', 'summit', 'trump', 'denuclear', 'south', 'korea']
# Donald Trump
# =====================================================================================
# Mark Zuckerberg's EU parliament appearance leaves a lot of tough questions unanswered
# ['mark', 'zuckerberg', 'parliament', 'appear', 'leav', 'lot', 'tough', 'question', 'unansw']
# Mark Zuckerberg
# =====================================================================================
# In Russia, France's Macron Tries His Next Charm Offensive On 'Cher Vladimir'
# ['russia', 'franc', 'macron', 'tri', 'his', 'next', 'charm', 'offens', 'cher', 'vladimir']
# Vladimir Putin
# =====================================================================================
# Meghan's own Coat of Arms has been approved
# ['meghan', 'coat', 'arm', 'approv']
# Australia
# =====================================================================================
# Rohingya deserve non-violent leadership
# ['rohingya', 'deserv', 'non', 'violent', 'leadership']
# Myanmar
# =====================================================================================
# Kim Jong-un's quandry: How Donald Trump's promises could lead to a coup
# ['kim', 'jong', 'quandri', 'how', 'donald', 'trump', 'promis', 'could', 'lead', 'coup']
# North Korea
# =====================================================================================
# Hillary Clinton jokes that she wouldn't mind being CEO of Facebook (FB)
# ['hillari', 'clinton', 'joke', 'mind', 'ceo', 'facebook']
# US Visa
# =====================================================================================
# Regime change in Iran could cost the US trillions
# ['regim', 'chang', 'iran', 'could', 'cost', 'trillion']
# Iran
# =====================================================================================
# US de facto embassy in Taiwan reopens as 'symbol of strength' of ties
# ['facto', 'embassi', 'taiwan', 'reopen', 'symbol', 'strength', 'tie']
# Malaysia
# =====================================================================================
# Ivanka Trump's "Chinese Proverb" Tweet Leaves China Puzzled
# ['ivanka', 'trump', 'chines', 'proverb', 'tweet', 'leav', 'china', 'puzzl']
# Ivanka Trump
# =====================================================================================
# Robert Kuok part of Malaysian PM Mahathir Mohamad's plans for strong ties with China
# ['robert', 'kuok', 'part', 'malaysian', 'mahathir', 'mohamad', 'plan', 'strong', 'tie', 'china']
# Cyclone
# =====================================================================================
# Stocks Rise, Investors Cheer Easing Trade Tensions: Markets Wrap
# ['stock', 'rise', 'investor', 'cheer', 'eas', 'trade', 'tension', 'market', 'wrap']
# USA
# =====================================================================================
# Nawaz Sharif Warns Of "Consequences" For Dragging His Daughter To Court In Panama Papers Case
# ['nawaz', 'sharif', 'warn', 'consequ', 'for', 'drag', 'his', 'daughter', 'court', 'panama', 'paper', 'case']
# Pakistan
# =====================================================================================
# 'Startup visa' rule in doubt after feds publish plan to end it
# ['startup', 'visa', 'rule', 'doubt', 'fed', 'publish', 'plan', 'end']
# Malaysia
# =====================================================================================
# School shooting reported at Noblesville West Middle School
# ['school', 'shoot', 'report', 'noblesvill', 'west', 'middl', 'school']
# Crime
# =====================================================================================
# Bangladeshi writer shot dead
# ['bangladeshi', 'writer', 'shot', 'dead']
# Bangladesh
# =====================================================================================
# Colombians vote for new President with peace deal, economy at stake
# ['colombian', 'vote', 'new', 'presid', 'peac', 'deal', 'economi', 'stake']
# Colombia
# =====================================================================================
# Brexit: Justice minister Phillip Lee resigns ahead of key debate - Politics live
# ['brexit', 'justic', 'minist', 'phillip', 'lee', 'resign', 'ahead', 'key', 'debat', 'polit', 'live']
# Britain
# =====================================================================================
# US unveils new de facto embassy in Taiwan
# ['unveil', 'new', 'facto', 'embassi', 'taiwan']
# USA
# =====================================================================================
# US Staffer Suffers Brain Injury After 'Sound' Incident In China
# ['staffer', 'suffer', 'brain', 'injuri', 'after', 'sound', 'incid', 'china']
# USA
# =====================================================================================
# Theresa May survives another week – but one day the Brexit road will run out
# ['theresa', 'may', 'surviv', 'anoth', 'week', 'one', 'day', 'brexit', 'road', 'run']
# Terrorism
# =====================================================================================
# Donald Trump's economic adviser Kudlow in 'good' condition after heart attack
# ['donald', 'trump', 'econom', 'advis', 'kudlow', 'good', 'condit', 'heart', 'attack']
# Donald Trump
# =====================================================================================
# Irish abortion campaigners recount #HomeToVote journeys online
# ['irish', 'abort', 'campaign', 'recount', 'hometovot', 'journey', 'onlin']
# Ireland
# =====================================================================================
# Facebook suggests no compensation for European users affected by data breach
# ['facebook', 'suggest', 'compens', 'european', 'user', 'affect', 'data', 'breach']
# Mark Zuckerberg
# =====================================================================================
# All you need to know about Ireland's referendum on legalising abortion
# ['all', 'need', 'know', 'ireland', 'referendum', 'legalis', 'abort']
# Ireland
# =====================================================================================
# Pakistani Girl Killed In Texas School Shooting Buried In Karachi
# ['pakistani', 'girl', 'kill', 'texa', 'school', 'shoot', 'buri', 'karachi']
# Pakistan
# =====================================================================================
# South Korea has spycam porn problem and now women in Seoul are marching on streets seeking action against it
# ['south', 'korea', 'spycam', 'porn', 'problem', 'women', 'seoul', 'march', 'street', 'seek', 'action']
# USA
# =====================================================================================
# Merkel, Chinese premier defend Iran deal, free trade
# ['merkel', 'chines', 'premier', 'defend', 'iran', 'deal', 'free', 'trade']
# Iran
# =====================================================================================
# Missed opportunity: on cancellation of Trump-Kim summit
# ['miss', 'opportun', 'cancel', 'trump', 'kim', 'summit']
# Kim Jong Un
# =====================================================================================
# At least four killed, 15 wounded in Baghdad bomb blast
# ['least', 'four', 'kill', 'wound', 'baghdad', 'bomb', 'blast']
# Iraq
# =====================================================================================
# As Italy's new leaders get tough on migrants, Spain steps up
# ['itali', 'new', 'leader', 'get', 'tough', 'migrant', 'spain', 'step']
# Narendra Modi
# =====================================================================================
# German Chancellor Merkel Meets With Wife of Detained Human Rights Lawyer, Yu Wensheng
# ['german', 'chancellor', 'merkel', 'meet', 'with', 'wife', 'detain', 'human', 'right', 'lawyer', 'wensheng']
# Crime
# =====================================================================================
# India-US ties: Narendra Modi's China, Russia visits have brought underlying tensions in bilateral ties to surface
# ['india', 'tie', 'narendra', 'modi', 'china', 'russia', 'visit', 'brought', 'under', 'tension', 'bilater', 'tie', 'surfac']
# Malaysia
# =====================================================================================
# Iraq says suicide bomber kills 7 in northern Baghdad park
# ['iraq', 'say', 'suicid', 'bomber', 'kill', 'northern', 'baghdad', 'park']
# Iraq
# =====================================================================================
# Cyclone Mekunu Pounds Yemen Island on Its Path to Oman
# ['cyclon', 'mekunu', 'pound', 'yemen', 'island', 'it', 'path', 'oman']
# Cyclone
# =====================================================================================
# Who was Shahzahan Bachchu? Prominent Bangladeshi writer and secularist gunned down
# ['who', 'shahzahan', 'bachchu', 'promin', 'bangladeshi', 'writer', 'secularist', 'gun']
# Bangladesh
# =====================================================================================
# Revoking of work visa of spouses of H-1B holders in final stages: US
# ['revok', 'work', 'visa', 'spous', 'holder', 'final', 'stage']
# US Visa
# =====================================================================================
# Colombians vote for new president in wake of Farc peace process
# ['colombian', 'vote', 'new', 'presid', 'wake', 'farc', 'peac', 'process']
# Colombia
# =====================================================================================
# Arjun Vajpayi conquers Kangchenjunga, youngest to scale 6 peaks above 8000m
# ['arjun', 'vajpayi', 'conquer', 'kangchenjunga', 'youngest', 'scale', 'peak', '8000m']
# India
# =====================================================================================
# India should play key role in Rohingyas' repatriation, says Bangladesh PM Sheikh Hasina
# ['india', 'play', 'key', 'role', 'rohingya', 'repatri', 'say', 'bangladesh', 'sheikh', 'hasina']
# Narendra Modi
# =====================================================================================
# Britain's May refuses to relax Northern Ireland abortion rules
# ['britain', 'may', 'refus', 'relax', 'northern', 'ireland', 'abort', 'rule']
# Britain
# =====================================================================================
# No lawyer willing to fight my case, claims ex-Pak PM Nawaz Sharif
# ['lawyer', 'will', 'fight', 'case', 'claim', 'pak', 'nawaz', 'sharif']
# Pakistan
# =====================================================================================
# Royal Wedding 2018: Meghan Markle coat of arms revealed
# ['royal', 'wed', '2018', 'meghan', 'markl', 'coat', 'arm', 'reveal']
# Celebrity
# =====================================================================================
# Heatwave kills 65 people in Pakistan as scorching 44C temperatures persist
# ['heatwav', 'kill', 'peopl', 'pakistan', 'scorch', '44c', 'temperatur', 'persist']
# Pakistan
# =====================================================================================
# 'Mother of all thunderstorms' delivers up to 20000 lightning strikes – as Stansted fuel system hit
# ['mother', 'thunderstorm', 'deliv', '20000', 'lightn', 'strike', 'stanst', 'fuel', 'system', 'hit']
# Britain
# =====================================================================================
# After pummeling Yemeni island, Cyclone Mekunu shuts down Oman's airport
# ['after', 'pummel', 'yemeni', 'island', 'cyclon', 'mekunu', 'shut', 'oman', 'airport']
# Cyclone
# =====================================================================================
# Ireland abortion referendum: What you need to know
# ['ireland', 'abort', 'referendum', 'what', 'need', 'know']
# Ireland
# =====================================================================================
# Judge rules Trump can't block users on Twitter
# ['judg', 'rule', 'trump', 'block', 'user', 'twitter']
# Donald Trump
# =====================================================================================
# Russian army missile launcher fired rocket that brought down MH17, say investigators
# ['russian', 'armi', 'missil', 'launcher', 'fire', 'rocket', 'brought', 'mh17', 'say', 'investig']
# Malaysia
# =====================================================================================
# Spain saves over 500 migrants at sea
# ['spain', 'save', '500', 'migrant', 'sea']
# Italy
# =====================================================================================
# PM opens new building of GB Legislative Assembly
# ['open', 'new', 'build', 'legisl', 'assembl']
# India
# =====================================================================================
# Trump, Visiting Epicenter of MS-13 Killings, Demands Tougher Immigration Laws
# ['trump', 'visit', 'epicent', 'kill', 'demand', 'tougher', 'immigr', 'law']
# USA
# =====================================================================================
